# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt # This is all you need to import keras.datasets.mnist.load_data()



# these imports are for afer cell 92
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization


pixel_width = 28
pixel_height = 28
batch_size = 32
num_of_classes = 10
epochs=10


(features_train, labels_train), (features_test, labels_test) = keras.datasets.mnist.load_data()
#print(features_train.shape)


features_train = features_train.reshape(features_train.shape[0],pixel_width,pixel_height,1)
#print(features_train.shape)

features_test = features_test.reshape(features_test.shape[0],pixel_width,pixel_height,1)
#print(features_test.shape)


input_shape = (pixel_width, pixel_height,1)

features_train =features_train.astype('float32')
features_test =features_test.astype('float32')

features_train /=255
features_test /=255
#print(labels_train[5])


# flatten 2 into a binary class matrix
labels_train=keras.utils.to_categorical(labels_train, num_of_classes)
labels_test=keras.utils.to_categorical(labels_test,num_of_classes)
#print(labels_train[5])

# adding batch noramlization

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(BatchNormalization())  
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  
model.add(Dense(num_of_classes, activation='softmax'))

# Compile with Adam optimizer and learning rate
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy']
)

model.fit(features_train, labels_train,
          batch_size=batch_size,
          epochs=20,  
          verbose=1,
          validation_data=(features_test, labels_test))

score = model.evaluate(features_test, labels_test, verbose=0)
print(score)
# Out:
# C:\ProgramData\anaconda3\envs\mnist_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 136s 72ms/step - accuracy: 0.8364 - loss: 0.6016 - val_accuracy: 0.9781 - val_loss: 0.0934
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 135s 72ms/step - accuracy: 0.9548 - loss: 0.1682 - val_accuracy: 0.9822 - val_loss: 0.0707
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 135s 72ms/step - accuracy: 0.9660 - loss: 0.1182 - val_accuracy: 0.9849 - val_loss: 0.0575
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 139s 74ms/step - accuracy: 0.9702 - loss: 0.1026 - val_accuracy: 0.9851 - val_loss: 0.0547
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 137s 73ms/step - accuracy: 0.9770 - loss: 0.0797 - val_accuracy: 0.9829 - val_loss: 0.0637
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 136s 72ms/step - accuracy: 0.9811 - loss: 0.0683 - val_accuracy: 0.9899 - val_loss: 0.0386
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 137s 73ms/step - accuracy: 0.9809 - loss: 0.0651 - val_accuracy: 0.9884 - val_loss: 0.0394
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 137s 73ms/step - accuracy: 0.9836 - loss: 0.0553 - val_accuracy: 0.9908 - val_loss: 0.0373
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 134s 71ms/step - accuracy: 0.9860 - loss: 0.0457 - val_accuracy: 0.9914 - val_loss: 0.0348
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 118s 63ms/step - accuracy: 0.9874 - loss: 0.0438 - val_accuracy: 0.9912 - val_loss: 0.0346
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 119s 63ms/step - accuracy: 0.9879 - loss: 0.0395 - val_accuracy: 0.9907 - val_loss: 0.0403
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 121s 65ms/step - accuracy: 0.9892 - loss: 0.0366 - val_accuracy: 0.9913 - val_loss: 0.0334
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 124s 66ms/step - accuracy: 0.9898 - loss: 0.0340 - val_accuracy: 0.9914 - val_loss: 0.0339
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 121s 64ms/step - accuracy: 0.9903 - loss: 0.0314 - val_accuracy: 0.9903 - val_loss: 0.0366
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 120s 64ms/step - accuracy: 0.9907 - loss: 0.0290 - val_accuracy: 0.9884 - val_loss: 0.0458
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 121s 64ms/step - accuracy: 0.9901 - loss: 0.0323 - val_accuracy: 0.9920 - val_loss: 0.0315
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 120s 64ms/step - accuracy: 0.9928 - loss: 0.0242 - val_accuracy: 0.9887 - val_loss: 0.0477
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 118s 63ms/step - accuracy: 0.9920 - loss: 0.0262 - val_accuracy: 0.9912 - val_loss: 0.0384
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 119s 63ms/step - accuracy: 0.9924 - loss: 0.0247 - val_accuracy: 0.9914 - val_loss: 0.0466
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 119s 63ms/step - accuracy: 0.9937 - loss: 0.0219 - val_accuracy: 0.9911 - val_loss: 0.0349
# [0.03485929220914841, 0.991100013256073]
